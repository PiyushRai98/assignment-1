# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushRai98/assignment-1/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PiyushRai98/assignment-1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# Verifying the binary nature of our task (example)
task_type = "Binary Classification"
num_classes = 2
print(f"Task: {task_type} with {num_classes} outcomes (Churned or Retained).")
# Out:
# Task: Binary Classification with 2 outcomes (Churned or Retained).

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# Checking the distribution of our observed target variable
target_variable = "churned"
print(f"Target column '{target_variable}' directly measures the observed cancellation event.")
# Out:
# Target column 'churned' directly measures the observed cancellation event.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# Defining our success threshold
target_recall = 0.80
print(f"Success is defined as achieving a Recall score of >= {target_recall * 100}%")
# Out:
# Success is defined as achieving a Recall score of >= 80.0%

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Simulating the dataframe slice for the unit of analysis
data = {
    'customer_id': ['C101', 'C102', 'C103'],
    'days_active': [340, 45, 1200],
    'logins_last_30d': [2, 15, 20],
    'support_tickets': [1, 0, 0],
    'churned': [1, 0, 0] # The observed outcome label
}

df = pd.DataFrame(data)
display(df)
# Out:
#   customer_id  days_active  logins_last_30d  support_tickets  churned
# 0        C101          340                2                1        1
# 1        C102           45               15                0        0
# 2        C103         1200               20                0        0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# No code strictly needed for this conceptual answer, but we can leave a clean check
print("Condition met: Problem requires complex pattern recognition beyond simple heuristics.")
# Out:
# Condition met: Problem requires complex pattern recognition beyond simple heuristics.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
